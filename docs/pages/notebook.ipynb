# %% [markdown]
# # Example coding page from Jupyter Notebook

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# > Jupyter Notebooks are not supported out-of-the-box, and require the use of the `mkdocs-jupyter` extension, [which can be found here](https://github.com/danielfrg/mkdocs-jupyter).
#
# > LaTeX-style equations are not supported out of the box, and require [this modification](https://squidfunk.github.io/mkdocs-material/reference/math/#mathjax) and [this bodge](https://github.com/danielfrg/mkdocs-jupyter/issues/259#issuecomment-3847306434) for Notebooks.
#
# We will plot the equation
#
# $$y = x^2$$
#
# This text in this cell is written in Markdown, and the equation using LaTeX.

# %%
x = np.arange(0, 100)
y = x**2

# %%
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlabel("$x$")
ax.set_ylabel("$y$")
ax.set_title("$y = x^2$")
plt.show()
